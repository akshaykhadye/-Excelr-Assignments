# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sales = pd.read_csv("C:\\Users\\Akshay\\Downloads\\Company_Data.csv")

# %%
sales
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 0           17   Yes  Yes
# 1           10   Yes  Yes
# 2           12   Yes  Yes
# 3           14   Yes  Yes
# 4           13   Yes   No
# ..         ...   ...  ...
# 395         14   Yes  Yes
# 396         11    No  Yes
# 397         18   Yes  Yes
# 398         12   Yes  Yes
# 399         16   Yes  Yes
#
# [400 rows x 11 columns]

# %%
sales.shape
# Out:
# (400, 11)

# %%
sales.columns
# Out:
# Index(['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price',
#        'ShelveLoc', 'Age', 'Education', 'Urban', 'US'],
#       dtype='object')

# %%
sales.dtypes
# Out:
# Sales          float64
# CompPrice        int64
# Income           int64
# Advertising      int64
# Population       int64
# Price            int64
# ShelveLoc       object
# Age              int64
# Education        int64
# Urban           object
# US              object
# dtype: object

# %%
sales['Sales'] = sales['Sales'].astype('int64')

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    int64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: int64(8), object(3)
# memory usage: 34.5+ KB

# %%
#no null values

# %%
sales.describe()
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     6.987500  124.975000   68.657500     6.635000  264.840000
# std      2.837688   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.000000  115.000000   42.750000     0.000000  139.000000
# 50%      7.000000  125.000000   69.000000     5.000000  272.000000
# 75%      9.000000  135.000000   91.000000    12.000000  398.500000
# max     16.000000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age   Education
# count  400.000000  400.000000  400.000000
# mean   115.795000   53.322500   13.900000
# std     23.676664   16.200297    2.620528
# min     24.000000   25.000000   10.000000
# 25%    100.000000   39.750000   12.000000
# 50%    117.000000   54.500000   14.000000
# 75%    131.000000   66.000000   16.000000
# max    191.000000   80.000000   18.000000

# %%
#dosent seem like there are many outliers

# %%
sales[sales['Sales']>10]
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 1       11        111      48           16         260     83      Good   65
# 7       11        136      81           15         425    120      Good   67
# 11      11        117      94            4         503     94      Good   50
# 14      11        107     117           11         148    118      Good   52
# 17      12        147      74           13         251    131      Good   52
# 18      13        110     110            0         408     68      Good   46
# 21      12        134      29           12         239    109      Good   62
# 25      14        139      32            0         176     82      Good   54
# 30      13        125      94            0         447     89      Good   30
# 35      11        131      84           11          29     96    Medium   44
# 46      12        127      90           14          16     70    Medium   48
# 56      11        133      82            0          54     84    Medium   50
# 68      13        149      69           20         366    134      Good   60
# 73      12        118      90           10          54    104      Good   31
# 82      11        151      83            4         325    139      Good   28
# 87      11        131      67            7         272    126      Good   54
# 98      12        122      77           24         382    127      Good   36
# 121     11        125      89           10         380     87       Bad   28
# 126     11        153      68            2          60    133      Good   59
# 139     12        146      62           10         310     94    Medium   30
# 149     11        121     120           13         140     87    Medium   56
# 158     12        142      90            1         189    112      Good   39
# 169     11        104      41           15         492     77      Good   73
# 171     12         93     106           12         416     55    Medium   75
# 189     12        118     117           18         509    104    Medium   26
# 193     13        139      70            7          71     96      Good   61
# 212     12        145      69           19         501    105    Medium   45
# 229     11         98     104            0         404     72    Medium   27
# 232     13        137      80           10          24    105      Good   61
# 241     12        136      63            0         160     94    Medium   38
# 270     11        119      26            0         284     89      Good   26
# 272     12        113      33            0          14     63      Good   38
# 281     11        122      69            7         303    105      Good   45
# 292     11        113      66           16         322     74      Good   76
# 293     11        123      84            0          74     89      Good   59
# 294     12        148      76            3         126     99      Good   60
# 304     11        123      98           12         408    134      Good   29
# 309     11        131     111           13          33     80       Bad   68
# 316     15        122      36            5         369     72      Good   35
# 325     11        144      69           11         131    104    Medium   47
# 329     11        100      54            9         433     89      Good   45
# 339     11        134      44            4         219    126      Good   44
# 348     12        132     102           20         459    107      Good   49
# 352     13        133     103           14         288    122      Good   61
# 357     13        103      73            3         276     72    Medium   34
# 367     14         95     106            0         256     53      Good   52
# 376     16        141      60           19         319     92      Good   44
# 384     12        123      37           15         348    112      Good   28
# 395     12        138     108           17         203    128      Good   33
#
#      Education Urban   US
# 1           10   Yes  Yes
# 7           10   Yes  Yes
# 11          13   Yes  Yes
# 14          18   Yes  Yes
# 17          10   Yes  Yes
# 18          17    No  Yes
# 21          18    No  Yes
# 25          11    No   No
# 30          12   Yes   No
# 35          17    No  Yes
# 46          15    No  Yes
# 56          17   Yes   No
# 68          13   Yes  Yes
# 73          11    No  Yes
# 82          17   Yes  Yes
# 87          16    No  Yes
# 98          16    No  Yes
# 121         10   Yes  Yes
# 126         16   Yes  Yes
# 139         13    No  Yes
# 149         11   Yes  Yes
# 158         10    No  Yes
# 169         18   Yes  Yes
# 171         15   Yes  Yes
# 189         15    No  Yes
# 193         10   Yes  Yes
# 212         11   Yes  Yes
# 229         18    No   No
# 232         15   Yes  Yes
# 241         12   Yes   No
# 270         10   Yes   No
# 272         12   Yes   No
# 281         16    No  Yes
# 292         15   Yes  Yes
# 293         10   Yes   No
# 294         11   Yes  Yes
# 304         10   Yes  Yes
# 309         18   Yes  Yes
# 316         10   Yes  Yes
# 325         11   Yes  Yes
# 329         12   Yes  Yes
# 339         15   Yes  Yes
# 348         11   Yes  Yes
# 352         17   Yes  Yes
# 357         15   Yes  Yes
# 367         17   Yes   No
# 376         11   Yes  Yes
# 384         12   Yes  Yes
# 395         14   Yes  Yes

# %%
sales[sales['Sales']<10]
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0        9        138      73           11         276    120       Bad   42
# 3        7        117     100            4         466     97    Medium   55
# 4        4        141      64            3         340    128       Bad   38
# 6        6        115     105            0          45    108    Medium   71
# 8        6        132     110            0         108    124    Medium   76
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 394      5        130      58           19         366    139       Bad   33
# 396      6        139      23            3          37    120    Medium   55
# 397      7        162      26           12         368    159    Medium   40
# 398      5        100      79            7         284     95       Bad   50
# 399      9        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 0           17   Yes  Yes
# 3           14   Yes  Yes
# 4           13   Yes   No
# 6           15   Yes   No
# 8           10    No   No
# ..         ...   ...  ...
# 394         16   Yes  Yes
# 396         11    No  Yes
# 397         18   Yes  Yes
# 398         12   Yes  Yes
# 399         16   Yes  Yes
#
# [321 rows x 11 columns]

# %%
sales['Sales'].mean()
# Out:
# 6.9875

# %%
sales[sales['Sales'] > 7.5]
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0        9        138      73           11         276    120       Bad   42
# 1       11        111      48           16         260     83      Good   65
# 2       10        113      35           10         269     80    Medium   59
# 5       10        124     113           13         501     72       Bad   78
# 7       11        136      81           15         425    120      Good   67
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 387      8        142      73           14         238    115    Medium   73
# 388      8        135      89           11         245     78       Bad   79
# 389      8        128      42            8         328    107    Medium   35
# 395     12        138     108           17         203    128      Good   33
# 399      9        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 0           17   Yes  Yes
# 1           10   Yes  Yes
# 2           12   Yes  Yes
# 5           16    No  Yes
# 7           10   Yes  Yes
# ..         ...   ...  ...
# 387         14    No  Yes
# 388         16   Yes  Yes
# 389         12   Yes  Yes
# 395         14   Yes  Yes
# 399         16   Yes  Yes
#
# [164 rows x 11 columns]

# %%
sales[sales['Sales'] < 7.5]
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 3        7        117     100            4         466     97    Medium   55
# 4        4        141      64            3         340    128       Bad   38
# 6        6        115     105            0          45    108    Medium   71
# 8        6        132     110            0         108    124    Medium   76
# 9        4        132     113            0         131    124    Medium   76
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 393      5        109      51           10          26    120    Medium   30
# 394      5        130      58           19         366    139       Bad   33
# 396      6        139      23            3          37    120    Medium   55
# 397      7        162      26           12         368    159    Medium   40
# 398      5        100      79            7         284     95       Bad   50
#
#      Education Urban   US
# 3           14   Yes  Yes
# 4           13   Yes   No
# 6           15   Yes   No
# 8           10    No   No
# 9           17    No  Yes
# ..         ...   ...  ...
# 393         17    No  Yes
# 394         16   Yes  Yes
# 396         11    No  Yes
# 397         18   Yes  Yes
# 398         12   Yes  Yes
#
# [236 rows x 11 columns]

# %%
sales['Sales'] = sales['Sales'].apply(lambda x: 'high' if x > 7.5 else 'low')

# %%
sales.head(10)
# Out:
#   Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0  high        138      73           11         276    120       Bad   42
# 1  high        111      48           16         260     83      Good   65
# 2  high        113      35           10         269     80    Medium   59
# 3   low        117     100            4         466     97    Medium   55
# 4   low        141      64            3         340    128       Bad   38
# 5  high        124     113           13         501     72       Bad   78
# 6   low        115     105            0          45    108    Medium   71
# 7  high        136      81           15         425    120      Good   67
# 8   low        132     110            0         108    124    Medium   76
# 9   low        132     113            0         131    124    Medium   76
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No
# 5         16    No  Yes
# 6         15   Yes   No
# 7         10   Yes  Yes
# 8         10    No   No
# 9         17    No  Yes

# %%
sales['Sales'].value_counts()
# Out:
# low     236
# high    164
# Name: Sales, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lc = LabelEncoder()

# %%
sales['Sales'] = lc.fit_transform(sales['Sales'])

# %%
sales['Urban'] = lc.fit_transform(sales['Urban'])

# %%
sales['US'] = lc.fit_transform(sales['US'])

# %%
sales['ShelveLoc'] = lc.fit_transform(sales['ShelveLoc'])

# %%
sales
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0        0        138      73           11         276    120          0   42
# 1        0        111      48           16         260     83          1   65
# 2        0        113      35           10         269     80          2   59
# 3        1        117     100            4         466     97          2   55
# 4        1        141      64            3         340    128          0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395      0        138     108           17         203    128          1   33
# 396      1        139      23            3          37    120          2   55
# 397      1        162      26           12         368    159          2   40
# 398      1        100      79            7         284     95          0   50
# 399      0        134      37            0          27    120          1   49
#
#      Education  Urban  US
# 0           17      1   1
# 1           10      1   1
# 2           12      1   1
# 3           14      1   1
# 4           13      1   0
# ..         ...    ...  ..
# 395         14      1   1
# 396         11      0   1
# 397         18      1   1
# 398         12      1   1
# 399         16      1   1
#
# [400 rows x 11 columns]

# %%
sales.drop('Education' , axis  =1 ,inplace = True)

# %%
sales.shape
# Out:
# (400, 10)

# %%
sns.boxplot(sales['Age'])
# Out:
# C:\Users\Akshay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(sales['Price'])
# Out:
# C:\Users\Akshay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price'>

# %%
sns.boxplot(sales['Population'])
# Out:
# C:\Users\Akshay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Population'>

# %%
sns.boxplot(sales['Advertising'])
# Out:
# C:\Users\Akshay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Advertising'>

# %%
sns.boxplot(sales['CompPrice'])
# Out:
# C:\Users\Akshay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CompPrice'>

# %%
sns.boxplot(sales['Income'])
# Out:
# C:\Users\Akshay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Income'>

# %%
plt.figure(figsize = (10,10))
sns.heatmap(sales.corr() , annot = True )
# Out:
# <AxesSubplot:>

# %%
x = sales.iloc[:,1:]

# %%
x
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  Urban  \
# 0          138      73           11         276    120          0   42      1
# 1          111      48           16         260     83          1   65      1
# 2          113      35           10         269     80          2   59      1
# 3          117     100            4         466     97          2   55      1
# 4          141      64            3         340    128          0   38      1
# ..         ...     ...          ...         ...    ...        ...  ...    ...
# 395        138     108           17         203    128          1   33      1
# 396        139      23            3          37    120          2   55      0
# 397        162      26           12         368    159          2   40      1
# 398        100      79            7         284     95          0   50      1
# 399        134      37            0          27    120          1   49      1
#
#      US
# 0     1
# 1     1
# 2     1
# 3     1
# 4     0
# ..   ..
# 395   1
# 396   1
# 397   1
# 398   1
# 399   1
#
# [400 rows x 9 columns]

# %%
y = sales['Sales']

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 395    0
# 396    1
# 397    1
# 398    1
# 399    0
# Name: Sales, Length: 400, dtype: int32

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size = 0.8,random_state=42)

# %%
x_train.shape
# Out:
# (320, 9)

# %%
x_test.shape
# Out:
# (80, 9)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree

# %%
dtree = DecisionTreeClassifier(random_state =0)

# %%
dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=0, splitter='best')

# %%
dtree.score(x_train,y_train)
# Out:
# 1.0

# %%
plt.figure(figsize = (15,15))

tree.plot_tree(dtree,filled=True)
# Out:
# [Text(238.134779676259, 784.0384615384615, 'X[4] <= 92.5\ngini = 0.479\nsamples = 320\nvalue = [127, 193]'),
#  Text(72.2589928057554, 721.3153846153846, 'X[5] <= 0.5\ngini = 0.292\nsamples = 45\nvalue = [37, 8]'),
#  Text(36.1294964028777, 658.5923076923077, 'X[2] <= 9.5\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(24.086330935251798, 595.8692307692307, 'X[0] <= 118.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(12.043165467625899, 533.1461538461538, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(36.1294964028777, 533.1461538461538, 'X[6] <= 42.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(24.086330935251798, 470.4230769230769, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(48.172661870503596, 470.4230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(48.172661870503596, 595.8692307692307, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(108.38848920863309, 658.5923076923077, 'X[0] <= 101.0\ngini = 0.114\nsamples = 33\nvalue = [31, 2]'),
#  Text(96.34532374100719, 595.8692307692307, 'X[4] <= 82.0\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(84.3021582733813, 533.1461538461538, 'X[3] <= 67.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(72.2589928057554, 470.4230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(96.34532374100719, 470.4230769230769, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(108.38848920863309, 533.1461538461538, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(120.43165467625899, 595.8692307692307, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]'),
#  Text(404.01056654676256, 721.3153846153846, 'X[2] <= 6.5\ngini = 0.44\nsamples = 275\nvalue = [90, 185]'),
#  Text(233.3363309352518, 658.5923076923077, 'X[6] <= 50.5\ngini = 0.298\nsamples = 148\nvalue = [27, 121]'),
#  Text(144.5179856115108, 595.8692307692307, 'X[5] <= 0.5\ngini = 0.459\nsamples = 56\nvalue = [20, 36]'),
#  Text(132.4748201438849, 533.1461538461538, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(156.5611510791367, 533.1461538461538, 'X[4] <= 103.5\ngini = 0.499\nsamples = 42\nvalue = [20, 22]'),
#  Text(144.5179856115108, 470.4230769230769, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(168.6043165467626, 470.4230769230769, 'X[1] <= 34.0\ngini = 0.482\nsamples = 37\nvalue = [15, 22]'),
#  Text(156.5611510791367, 407.7, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(180.6474820143885, 407.7, 'X[0] <= 131.0\ngini = 0.499\nsamples = 29\nvalue = [15, 14]'),
#  Text(150.53956834532374, 344.9769230769231, 'X[4] <= 114.5\ngini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(126.45323741007194, 282.2538461538461, 'X[0] <= 103.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(114.41007194244604, 219.53076923076924, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(138.49640287769785, 219.53076923076924, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(174.62589928057554, 282.2538461538461, 'X[4] <= 150.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(162.58273381294964, 219.53076923076924, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(186.66906474820144, 219.53076923076924, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(210.75539568345323, 344.9769230769231, 'X[6] <= 33.5\ngini = 0.444\nsamples = 18\nvalue = [12, 6]'),
#  Text(198.71223021582733, 282.2538461538461, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(222.79856115107913, 282.2538461538461, 'X[1] <= 57.0\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(210.75539568345323, 219.53076923076924, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(234.84172661870502, 219.53076923076924, 'X[4] <= 124.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(222.79856115107913, 156.80769230769226, 'X[3] <= 152.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(210.75539568345323, 94.0846153846154, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(234.84172661870502, 94.0846153846154, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(246.88489208633092, 156.80769230769226, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(322.1546762589928, 595.8692307692307, 'X[0] <= 147.5\ngini = 0.141\nsamples = 92\nvalue = [7, 85]'),
#  Text(289.0359712230216, 533.1461538461538, 'X[1] <= 75.0\ngini = 0.111\nsamples = 85\nvalue = [5, 80]'),
#  Text(258.9280575539568, 470.4230769230769, 'X[6] <= 79.5\ngini = 0.038\nsamples = 51\nvalue = [1, 50]'),
#  Text(246.88489208633092, 407.7, 'gini = 0.0\nsamples = 45\nvalue = [0, 45]'),
#  Text(270.9712230215827, 407.7, 'X[4] <= 104.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(258.9280575539568, 344.9769230769231, 'X[1] <= 56.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(246.88489208633092, 282.2538461538461, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(270.9712230215827, 282.2538461538461, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(283.0143884892086, 344.9769230769231, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(319.1438848920863, 470.4230769230769, 'X[1] <= 77.5\ngini = 0.208\nsamples = 34\nvalue = [4, 30]'),
#  Text(307.1007194244604, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(331.1870503597122, 407.7, 'X[7] <= 0.5\ngini = 0.165\nsamples = 33\nvalue = [3, 30]'),
#  Text(307.1007194244604, 344.9769230769231, 'X[5] <= 1.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(295.0575539568345, 282.2538461538461, 'X[6] <= 71.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(283.0143884892086, 219.53076923076924, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(307.1007194244604, 219.53076923076924, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(319.1438848920863, 282.2538461538461, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(355.273381294964, 344.9769230769231, 'X[0] <= 133.5\ngini = 0.074\nsamples = 26\nvalue = [1, 25]'),
#  Text(343.2302158273381, 282.2538461538461, 'gini = 0.0\nsamples = 21\nvalue = [0, 21]'),
#  Text(367.3165467625899, 282.2538461538461, 'X[4] <= 114.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(355.273381294964, 219.53076923076924, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(379.3597122302158, 219.53076923076924, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(355.273381294964, 533.1461538461538, 'X[3] <= 158.0\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(343.2302158273381, 470.4230769230769, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(367.3165467625899, 470.4230769230769, 'X[1] <= 58.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(355.273381294964, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(379.3597122302158, 407.7, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(574.6848021582733, 658.5923076923077, 'X[5] <= 0.5\ngini = 0.5\nsamples = 127\nvalue = [63, 64]'),
#  Text(451.61870503597123, 595.8692307692307, 'X[2] <= 15.5\ngini = 0.198\nsamples = 27\nvalue = [3, 24]'),
#  Text(427.53237410071944, 533.1461538461538, 'X[6] <= 26.5\ngini = 0.083\nsamples = 23\nvalue = [1, 22]'),
#  Text(415.48920863309354, 470.4230769230769, 'X[2] <= 9.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(403.44604316546764, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(427.53237410071944, 407.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(439.57553956834533, 470.4230769230769, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(475.705035971223, 533.1461538461538, 'X[1] <= 71.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(463.66187050359713, 470.4230769230769, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(487.7482014388489, 470.4230769230769, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(697.7508992805755, 595.8692307692307, 'X[4] <= 136.0\ngini = 0.48\nsamples = 100\nvalue = [60, 40]'),
#  Text(582.5881294964029, 533.1461538461538, 'X[0] <= 114.0\ngini = 0.436\nsamples = 84\nvalue = [57, 27]'),
#  Text(511.8345323741007, 470.4230769230769, 'X[5] <= 1.5\ngini = 0.444\nsamples = 18\nvalue = [6, 12]'),
#  Text(499.7913669064748, 407.7, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(523.8776978417266, 407.7, 'X[3] <= 399.0\ngini = 0.245\nsamples = 14\nvalue = [2, 12]'),
#  Text(511.8345323741007, 344.9769230769231, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(535.9208633093525, 344.9769230769231, 'X[3] <= 454.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(523.8776978417266, 282.2538461538461, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(547.9640287769784, 282.2538461538461, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(653.341726618705, 470.4230769230769, 'X[4] <= 127.5\ngini = 0.351\nsamples = 66\nvalue = [51, 15]'),
#  Text(590.115107913669, 407.7, 'X[1] <= 26.0\ngini = 0.227\nsamples = 46\nvalue = [40, 6]'),
#  Text(578.0719424460432, 344.9769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(602.158273381295, 344.9769230769231, 'X[0] <= 121.0\ngini = 0.198\nsamples = 45\nvalue = [40, 5]'),
#  Text(572.0503597122301, 282.2538461538461, 'X[6] <= 61.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(560.0071942446043, 219.53076923076924, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(584.0935251798561, 219.53076923076924, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(632.2661870503597, 282.2538461538461, 'X[4] <= 124.5\ngini = 0.102\nsamples = 37\nvalue = [35, 2]'),
#  Text(608.1798561151079, 219.53076923076924, 'X[2] <= 10.5\ngini = 0.059\nsamples = 33\nvalue = [32, 1]'),
#  Text(596.136690647482, 156.80769230769226, 'X[2] <= 9.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(584.0935251798561, 94.0846153846154, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(608.1798561151079, 94.0846153846154, 'X[0] <= 137.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(596.136690647482, 31.36153846153843, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(620.2230215827338, 31.36153846153843, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(620.2230215827338, 156.80769230769226, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]'),
#  Text(656.3525179856115, 219.53076923076924, 'X[4] <= 125.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(644.3093525179856, 156.80769230769226, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(668.3956834532374, 156.80769230769226, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(716.568345323741, 407.7, 'X[5] <= 1.5\ngini = 0.495\nsamples = 20\nvalue = [11, 9]'),
#  Text(680.4388489208633, 344.9769230769231, 'X[6] <= 65.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(668.3956834532374, 282.2538461538461, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(692.4820143884892, 282.2538461538461, 'X[4] <= 130.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(680.4388489208633, 219.53076923076924, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(704.5251798561151, 219.53076923076924, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(752.6978417266187, 344.9769230769231, 'X[0] <= 148.0\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(740.6546762589928, 282.2538461538461, 'X[6] <= 36.0\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(728.6115107913669, 219.53076923076924, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(752.6978417266187, 219.53076923076924, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(764.7410071942446, 282.2538461538461, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(812.9136690647482, 533.1461538461538, 'X[0] <= 168.5\ngini = 0.305\nsamples = 16\nvalue = [3, 13]'),
#  Text(800.8705035971223, 470.4230769230769, 'X[5] <= 1.5\ngini = 0.231\nsamples = 15\nvalue = [2, 13]'),
#  Text(788.8273381294964, 407.7, 'X[3] <= 268.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(776.7841726618705, 344.9769230769231, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(800.8705035971223, 344.9769230769231, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(812.9136690647482, 407.7, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(824.956834532374, 470.4230769230769, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %%
pred = dtree.predict(x_test)

# %%
accuracy_score(pred,y_test)
# Out:
# 0.725

# %% [markdown]
# # overfitting problem is observed

# %%
path = dtree.cost_complexity_pruning_path(x_train,y_train)

# %%
path
# Out:
# {'ccp_alphas': array([0.        , 0.0020202 , 0.00204248, 0.00273437, 0.00288186,
#         0.00298913, 0.00300481, 0.00345494, 0.00366981, 0.00391414,
#         0.00416667, 0.00416667, 0.00416667, 0.00416667, 0.00473485,
#         0.00507813, 0.00520833, 0.00520833, 0.0053442 , 0.00654762,
#         0.00692812, 0.00741575, 0.00833333, 0.00880208, 0.00889699,
#         0.009375  , 0.01010878, 0.01061869, 0.01428571, 0.01488095,
#         0.01706575, 0.01718619, 0.0202567 , 0.03175853, 0.04201937,
#         0.05921027]),
#  'impurities': array([0.        , 0.00606061, 0.01218806, 0.01765681, 0.02342053,
#         0.02939879, 0.0354084 , 0.0526831 , 0.06369253, 0.07543496,
#         0.07960162, 0.08376829, 0.08793496, 0.09210162, 0.10157132,
#         0.11680569, 0.12201403, 0.12722236, 0.13791077, 0.14445839,
#         0.16524276, 0.18749001, 0.20415668, 0.21295876, 0.22185575,
#         0.23123075, 0.25144832, 0.26206701, 0.27635272, 0.29123367,
#         0.30829942, 0.32548561, 0.3457423 , 0.37750083, 0.4195202 ,
#         0.47873047])}

# %%
ca = path.ccp_alphas

# %%
ca
# Out:
# array([0.        , 0.0020202 , 0.00204248, 0.00273437, 0.00288186,
#        0.00298913, 0.00300481, 0.00345494, 0.00366981, 0.00391414,
#        0.00416667, 0.00416667, 0.00416667, 0.00416667, 0.00473485,
#        0.00507813, 0.00520833, 0.00520833, 0.0053442 , 0.00654762,
#        0.00692812, 0.00741575, 0.00833333, 0.00880208, 0.00889699,
#        0.009375  , 0.01010878, 0.01061869, 0.01428571, 0.01488095,
#        0.01706575, 0.01718619, 0.0202567 , 0.03175853, 0.04201937,
#        0.05921027])

# %%
lista = []

for i in ca:
    tree = DecisionTreeClassifier(ccp_alpha = i)
    tree.fit(x_train,y_train)
    pred = tree.predict(x_test)
    lista.append(accuracy_score(y_test,pred))

# %%
plt.figure(figsize = (12,10))
plt.plot(ca,lista)

# %%
dtree = DecisionTreeClassifier(ccp_alpha = 0.005, random_state = 0)
dtree.fit(x_train,y_train)
pred = dtree.predict(x_test)
accuracy_score(y_test,pred)
# Out:
# 0.7625

# %%
dtree = DecisionTreeClassifier(ccp_alpha = 0.005, random_state = 0 , max_depth = 8)
dtree.fit(x_train,y_train)
pred = dtree.predict(x_test)
accuracy_score(y_test,pred)
# Out:
# 0.7875

# %%
dtree1 = DecisionTreeClassifier(ccp_alpha = 0.005, random_state = 0 , max_depth = 8 , criterion = 'entropy')
dtree1.fit(x_train,y_train)
pred = dtree1.predict(x_test)
accuracy_score(y_test,pred)
# Out:
# 0.7375

# %% [markdown]
# # final decision tree

# %%
tree2 = DecisionTreeClassifier(ccp_alpha = 0.005 , max_depth = 8)
tree2.fit(x_train,y_train)
pred = tree2.predict(x_test)
accuracy_score(y_test,pred)
# Out:
# 0.7875

# %%
from sklearn import tree

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import _tree

# %%
plt.figure(figsize = (15,15))

tree.plot_tree(tree2,filled=True)
# Out:
# [Text(234.4375, 770.1, 'X[4] <= 92.5\ngini = 0.479\nsamples = 320\nvalue = [127, 193]'),
#  Text(124.0, 679.5, 'X[5] <= 0.5\ngini = 0.292\nsamples = 45\nvalue = [37, 8]'),
#  Text(93.0, 588.9, 'X[2] <= 9.5\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(62.0, 498.3, 'X[0] <= 118.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(31.0, 407.7, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(93.0, 407.7, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(124.0, 498.3, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(155.0, 588.9, 'gini = 0.114\nsamples = 33\nvalue = [31, 2]'),
#  Text(344.875, 679.5, 'X[2] <= 6.5\ngini = 0.44\nsamples = 275\nvalue = [90, 185]'),
#  Text(217.0, 588.9, 'X[6] <= 50.5\ngini = 0.298\nsamples = 148\nvalue = [27, 121]'),
#  Text(186.0, 498.3, 'X[5] <= 0.5\ngini = 0.459\nsamples = 56\nvalue = [20, 36]'),
#  Text(155.0, 407.7, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(217.0, 407.7, 'X[4] <= 103.5\ngini = 0.499\nsamples = 42\nvalue = [20, 22]'),
#  Text(186.0, 317.1, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(248.0, 317.1, 'X[1] <= 34.0\ngini = 0.482\nsamples = 37\nvalue = [15, 22]'),
#  Text(217.0, 226.5, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(279.0, 226.5, 'X[0] <= 131.0\ngini = 0.499\nsamples = 29\nvalue = [15, 14]'),
#  Text(248.0, 135.89999999999998, 'gini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(310.0, 135.89999999999998, 'X[6] <= 33.5\ngini = 0.444\nsamples = 18\nvalue = [12, 6]'),
#  Text(279.0, 45.30000000000007, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(341.0, 45.30000000000007, 'gini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(248.0, 498.3, 'gini = 0.141\nsamples = 92\nvalue = [7, 85]'),
#  Text(472.75, 588.9, 'X[5] <= 0.5\ngini = 0.5\nsamples = 127\nvalue = [63, 64]'),
#  Text(310.0, 498.3, 'X[2] <= 15.5\ngini = 0.198\nsamples = 27\nvalue = [3, 24]'),
#  Text(279.0, 407.7, 'gini = 0.083\nsamples = 23\nvalue = [1, 22]'),
#  Text(341.0, 407.7, 'X[1] <= 71.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(310.0, 317.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(372.0, 317.1, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(635.5, 498.3, 'X[4] <= 136.0\ngini = 0.48\nsamples = 100\nvalue = [60, 40]'),
#  Text(496.0, 407.7, 'X[0] <= 114.0\ngini = 0.436\nsamples = 84\nvalue = [57, 27]'),
#  Text(434.0, 317.1, 'X[5] <= 1.5\ngini = 0.444\nsamples = 18\nvalue = [6, 12]'),
#  Text(403.0, 226.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(465.0, 226.5, 'X[4] <= 103.5\ngini = 0.245\nsamples = 14\nvalue = [2, 12]'),
#  Text(434.0, 135.89999999999998, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(496.0, 135.89999999999998, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(558.0, 317.1, 'X[4] <= 127.5\ngini = 0.351\nsamples = 66\nvalue = [51, 15]'),
#  Text(527.0, 226.5, 'gini = 0.227\nsamples = 46\nvalue = [40, 6]'),
#  Text(589.0, 226.5, 'X[5] <= 1.5\ngini = 0.495\nsamples = 20\nvalue = [11, 9]'),
#  Text(558.0, 135.89999999999998, 'gini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(620.0, 135.89999999999998, 'X[6] <= 36.0\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(589.0, 45.30000000000007, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(651.0, 45.30000000000007, 'gini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(775.0, 407.7, 'X[2] <= 23.0\ngini = 0.305\nsamples = 16\nvalue = [3, 13]'),
#  Text(744.0, 317.1, 'X[5] <= 1.5\ngini = 0.231\nsamples = 15\nvalue = [2, 13]'),
#  Text(713.0, 226.5, 'X[3] <= 268.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(682.0, 135.89999999999998, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(744.0, 135.89999999999998, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(775.0, 226.5, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(806.0, 317.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %% [markdown]
# # Price was taken as the first criteria based on which the first split was made

# %% [markdown]
# # sales highly dependant on advertising and Price

# %% [markdown]
# # Sales depends least on competetors price
