# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense, Activation,Layer,Lambda
import seaborn as sns
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
from mlxtend.plotting import plot_decision_regions

# %% [markdown]
# # 1 - Business Problem

# %% [markdown]
# PREDICT THE BURNED AREA OF FOREST FIRES WITH NEURAL NETWORKS

# %% [markdown]
# # 2 - Data collection and description

# %%
df = pd.read_csv("C:/Users/Akshay/Downloads/gas_turbines.csv")
df1 = df.copy()
df1
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# 0      3.1547  82.722
# 1      3.2363  82.776
# 2      3.2012  82.468
# 3      3.1923  82.670
# 4      3.2484  82.311
# ...       ...     ...
# 15034  4.5186  79.559
# 15035  4.8470  79.917
# 15036  7.9632  90.912
# 15037  6.2494  93.227
# 15038  4.9816  92.498
#
# [15039 rows x 11 columns]

# %%
df1.drop_duplicates()
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# 0      3.1547  82.722
# 1      3.2363  82.776
# 2      3.2012  82.468
# 3      3.1923  82.670
# 4      3.2484  82.311
# ...       ...     ...
# 15034  4.5186  79.559
# 15035  4.8470  79.917
# 15036  7.9632  90.912
# 15037  6.2494  93.227
# 15038  4.9816  92.498
#
# [15039 rows x 11 columns]

# %%
df1.isnull().sum()
# Out:
# AT      0
# AP      0
# AH      0
# AFDP    0
# GTEP    0
# TIT     0
# TAT     0
# TEY     0
# CDP     0
# CO      0
# NOX     0
# dtype: int64

# %%
df1.describe().T
# Out:
#         count         mean        std          min          25%        50%  \
# AT    15039.0    17.764381   7.574323     0.522300    11.408000    18.1860
# AP    15039.0  1013.199240   6.410760   985.850000  1008.900000  1012.8000
# AH    15039.0    79.124174  13.793439    30.344000    69.750000    82.2660
# AFDP  15039.0     4.200294   0.760197     2.087400     3.723900     4.1862
# GTEP  15039.0    25.419061   4.173916    17.878000    23.294000    25.0820
# TIT   15039.0  1083.798770  16.527806  1000.800000  1079.600000  1088.7000
# TAT   15039.0   545.396183   7.866803   512.450000   542.170000   549.8900
# TEY   15039.0   134.188464  15.829717   100.170000   127.985000   133.7800
# CDP   15039.0    12.102353   1.103196     9.904400    11.622000    12.0250
# CO    15039.0     1.972499   2.222206     0.000388     0.858055     1.3902
# NOX   15039.0    68.190934  10.470586    27.765000    61.303500    66.6010
#
#             75%        max
# AT      23.8625    34.9290
# AP    1016.9000  1034.2000
# AH      90.0435   100.2000
# AFDP     4.5509     7.6106
# GTEP    27.1840    37.4020
# TIT   1096.0000  1100.8000
# TAT    550.0600   550.6100
# TEY    140.8950   174.6100
# CDP     12.5780    15.0810
# CO       2.1604    44.1030
# NOX     73.9355   119.8900

# %%
for i in df1.columns:
    print(i)
    sns.boxplot(df1[i])
    plt.show()
# Out:
# AT
# C:\Users\Akshay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# AP
# C:\Users\Akshay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# AH
# C:\Users\Akshay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# AFDP
# C:\Users\Akshay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# GTEP
# C:\Users\Akshay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# TIT
# C:\Users\Akshay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# TAT
# C:\Users\Akshay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Akshay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# TEY
# C:\Users\Akshay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# CDP
# C:\Users\Akshay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# CO
# NOX
# C:\Users\Akshay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.rcParams["figure.figsize"] = 9,5

# %%
plt.figure(figsize=(16,5))
print("Skew: {}".format(df1['TEY'].skew()))
print("Kurtosis: {}".format(df1['TEY'].kurtosis()))
ax = sns.kdeplot(df1['TEY'],shade=True,color='g')
plt.xticks([i for i in range(0,1200,50)])
plt.show()
# Out:
# Skew: 0.14596270190452942
# Kurtosis: -0.4870582497451621

# %% [markdown]
# The Data is highly skewed and has large kurtosis value Majority of the forest fires do not cover a large area, most of the damaged area is under 100 hectares of land

# %%
dfa = df1[df1.columns[0:10]]
month_colum = dfa.select_dtypes(include='object').columns.tolist()

# %%
plt.figure(figsize=(16,10))
for i,col in enumerate(month_colum,1):
    plt.subplot(4,2,i)
    sns.countplot(data=dfa,y=col)
    plt.subplot(4,2,i+2)
    df1[col].value_counts(normalize=True).plot.bar()
    plt.ylabel(col)
    plt.xlabel('% distribution per category')
plt.tight_layout()
plt.show()

# %%
num_columns = dfa.select_dtypes(exclude='object').columns.tolist()

# %%
plt.figure(figsize=(18,40))
for i,col in enumerate(num_columns,1):
    plt.subplot(8,4,i)
    sns.kdeplot(df[col],color='g',shade=True)
    plt.subplot(8,4,i+10)
    df[col].plot.box()
plt.tight_layout() 
plt.show()
num_data = df[num_columns]
pd.DataFrame(data=[num_data.skew(),num_data.kurtosis()],index=['skewness','kurtosis'])
# Out:
#                 AT        AP        AH      AFDP      GTEP       TIT  \
# skewness -0.030710  0.107601 -0.681224  0.315150  0.370987 -1.133744
# kurtosis -0.987597  0.424070 -0.282476  0.281642 -0.618358  0.375232
#
#                TAT       TEY       CDP         CO
# skewness -1.485524  0.145963  0.263042   6.534577
# kurtosis  0.847637 -0.487058 -0.589420  82.518116

# %% [markdown]
# # Finding Correlation

# %%
corr = df1[df1.columns[0:11]].corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
df1.iloc[:,0:7]
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98
# ...       ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85
#
# [15039 rows x 7 columns]

# %%
df1.columns
# Out:
# Index(['AT', 'AP', 'AH', 'AFDP', 'GTEP', 'TIT', 'TAT', 'TEY', 'CDP', 'CO',
#        'NOX'],
#       dtype='object')

# %%
def norm_func(i):
    x = (i - i.min())/(i.max()-i.min())
    return (x)

# %%
df1 = norm_func(df1)

# %%
X = df1.drop(columns=['TEY'])
y = df1.iloc[:,7]

# %% [markdown]
# # 3 - Neural Network Model

# %%
from sklearn.preprocessing import scale
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 42)
X_train_scaled = scale(X_train)
X_test_scaled = scale(X_test)
X_test_scaled
# Out:
# array([[ 0.82623246, -0.43954308, -0.25924569, ...,  0.10039242,
#         -0.3796304 , -0.69217007],
#        [ 0.35282087,  0.23279782,  0.80230139, ..., -1.18541222,
#          0.39149515, -1.09475442],
#        [ 0.32839008, -0.07135639,  0.25312287, ...,  0.01665304,
#         -0.00296896, -0.31891741],
#        ...,
#        [-0.74071701,  0.37687087,  0.43427425, ...,  1.77157829,
#         -1.00127821, -0.4818816 ],
#        [-0.49965786, -0.39151873,  0.64680105, ..., -0.26517949,
#         -0.48137538,  0.12808615],
#        [ 0.13151427,  0.32884652,  0.98830762, ..., -1.40331469,
#          0.13152215, -0.64456466]])

# %%
import tensorflow as tf

# %%
input_size = len(X.columns)
output_size = 1
hidden_layer_size = 50

model = tf.keras.Sequential([
                                
                               tf.keras.layers.Dense(hidden_layer_size, input_dim = input_size, activation = 'relu'),
                               tf.keras.layers.Dense(hidden_layer_size, activation = 'relu'),
                               tf.keras.layers.Dense(hidden_layer_size, activation = 'relu'),
                               tf.keras.layers.Dense(hidden_layer_size, activation = 'relu'),     
                               tf.keras.layers.Dense(output_size)
    
    
                                ])

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate = 0.03)
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['MeanSquaredError'])

# %%
num_epochs = 50
early_stopping = tf.keras.callbacks.EarlyStopping(patience = 2)
model.fit(X_train_scaled, y_train, callbacks = early_stopping, validation_split = 0.1, epochs = num_epochs, verbose = 2)
# Out:
# Epoch 1/50
# 381/381 - 2s - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 9.1712e-04 - val_mean_squared_error: 9.1712e-04 - 2s/epoch - 5ms/step
# Epoch 2/50
# 381/381 - 1s - loss: 3.8921e-04 - mean_squared_error: 3.8921e-04 - val_loss: 3.2070e-04 - val_mean_squared_error: 3.2070e-04 - 653ms/epoch - 2ms/step
# Epoch 3/50
# 381/381 - 1s - loss: 2.2030e-04 - mean_squared_error: 2.2030e-04 - val_loss: 2.0020e-04 - val_mean_squared_error: 2.0020e-04 - 747ms/epoch - 2ms/step
# Epoch 4/50
# 381/381 - 1s - loss: 1.6458e-04 - mean_squared_error: 1.6458e-04 - val_loss: 1.6204e-04 - val_mean_squared_error: 1.6204e-04 - 914ms/epoch - 2ms/step
# Epoch 5/50
# 381/381 - 1s - loss: 1.5795e-04 - mean_squared_error: 1.5795e-04 - val_loss: 2.0140e-04 - val_mean_squared_error: 2.0140e-04 - 847ms/epoch - 2ms/step
# Epoch 6/50
# 381/381 - 1s - loss: 1.3861e-04 - mean_squared_error: 1.3861e-04 - val_loss: 1.2925e-04 - val_mean_squared_error: 1.2925e-04 - 811ms/epoch - 2ms/step
# Epoch 7/50
# 381/381 - 1s - loss: 1.2169e-04 - mean_squared_error: 1.2169e-04 - val_loss: 1.1371e-04 - val_mean_squared_error: 1.1371e-04 - 848ms/epoch - 2ms/step
# Epoch 8/50
# 381/381 - 1s - loss: 1.0355e-04 - mean_squared_error: 1.0355e-04 - val_loss: 1.1815e-04 - val_mean_squared_error: 1.1815e-04 - 855ms/epoch - 2ms/step
# Epoch 9/50
# 381/381 - 1s - loss: 1.4862e-04 - mean_squared_error: 1.4862e-04 - val_loss: 1.2119e-04 - val_mean_squared_error: 1.2119e-04 - 865ms/epoch - 2ms/step

# %%
test_loss, mean_squared_error = model.evaluate(X_test_scaled, y_test)
# Out:
# 47/47 [==============================] - 0s 2ms/step - loss: 1.0515e-04 - mean_squared_error: 1.0515e-04

# %% [markdown]
# # 4 - Conclusion

# %%
predictions = model.predict_on_batch(X_test_scaled)

# %%
plt.scatter(y_test, predictions)

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation,Layer,Lambda

# %%
model = Sequential()
model.add(Dense(units=20,activation='relu'))
model.add(Dense(units=40,activation='tanh'))
model.add(Dense(units=10,activation='softmax'))

# %%
model.compile(optimizer='adam',loss='mean_squared_error',metrics=['mse'])

# %%
model.fit(X_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 423/423 [==============================] - 1s 1ms/step - loss: 0.1726 - mse: 0.1726
# Epoch 2/10
# 423/423 [==============================] - 0s 1ms/step - loss: 0.1726 - mse: 0.1726
# Epoch 3/10
# 423/423 [==============================] - 0s 1ms/step - loss: 0.1726 - mse: 0.1726
# Epoch 4/10
# 423/423 [==============================] - 0s 779us/step - loss: 0.1726 - mse: 0.1726
# Epoch 5/10
# 423/423 [==============================] - 0s 882us/step - loss: 0.1726 - mse: 0.1726
# Epoch 6/10
# 423/423 [==============================] - 0s 740us/step - loss: 0.1726 - mse: 0.1726
# Epoch 7/10
# 423/423 [==============================] - 0s 711us/step - loss: 0.1726 - mse: 0.1726
# Epoch 8/10
# 423/423 [==============================] - 0s 978us/step - loss: 0.1726 - mse: 0.1726
# Epoch 9/10
# 423/423 [==============================] - 0s 776us/step - loss: 0.1726 - mse: 0.1726
# Epoch 10/10
# 423/423 [==============================] - 0s 724us/step - loss: 0.1726 - mse: 0.1726

# %%
scores=model.evaluate(X_test,y_test)
scores
# Out:
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1737 - mse: 0.1737
# [0.17365118861198425, 0.17365118861198425]
